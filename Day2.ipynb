# %%
a=18
b=8

# %%
c= a+b

print (c)
# Out:
# 26

# %%
firstname='Shaukat'
print(firstname)
# Out:
# Shaukat

# %%
print(firstname.upper())
# Out:
# SHAUKAT

# %%
print(firstname.lower())
# Out:
# shaukat

# %%
#Introduction to  string Methods

# %%
name='Shock'
print(name)
type(name)
# Out:
# Shock
# str

# %%
age=22
print(age)
type(age)
# Out:
# 22
# int

# %%
secondname='Taufique'
print (secondname)
# Out:
# Taufique

# %%
print (firstname ,secondname.title())
# Out:
# Shaukat Taufique
