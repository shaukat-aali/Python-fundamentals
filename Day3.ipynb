# %%
#Introduction to F string:

# %%
#General Syntax of of string:

# %%
firstname= 'Shaukat'
lastname='aali'

# %%
#requirement: i want to get the full name...?

# %%
fullname= f"{firstname} {lastname}"
print(fullname)
# Out:
# Shaukat aali

# %%
print(fullname.title())
# Out:
# Shaukat Aali

# %%
message= f"keep up the good work,{fullname.title()}"
print(message)
# Out:
# keep up the good work,Shaukat Aali

# %%
print("favourite_Prog_Lang:PythonC++javascrptjavaSwift")
# Out:
# favourite_Prog_Lang:PythonC++javascrptjavaSwift

# %%
print("favourite_PRog_Lang:\nPython\nC++\njavascrpt\njavaSwift")
# Out:
# favourite_PRog_Lang:
# Python
# C++
# javascrpt
# javaSwift

# %%
print("favourite_PRog_Lang:\n\tPython\n\tC++\n\tjavascrpt\n\tjavaSwift")
# Out:
# favourite_PRog_Lang:
# 	Python
# 	C++
# 	javascrpt
# 	javaSwift

# %%
name= " Python"
name2="python "
print(name)
print(name2)
# Out:
#  Python
# python

# %%
name.lstrip()
# Out:
# 'Python'

# %%
name2.rstrip()
# Out:
# 'python'

# %%
name3="   Python    "
print(name)
# Out:
#    Python

# %%
name3.strip()
# Out:
# 'Python'

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
