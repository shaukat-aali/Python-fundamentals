# %%
#Introduction to Number

# %%
num=1 
num2=4

# %%
type(num)
# Out:
# int

# %%
x=0.01

# %%
type(x)
# Out:
# float

# %%
#Introduction to list datatype

# %%
students=['Viky' , 'abdul', 'shree','ansar', 'shuakat']

# %%
print(students)
# Out:
# ['Viky', 'abdul', 'shree', 'ansar', 'shuakat']

# %%
#introduction to indexing :- 0,1,2,3,4,5,,6...........

# %%
print(students[1])
# Out:
# abdul

# %%
print(students[1].title())
# Out:
# Abdul

# %%
#req:Add Arun to the list

# %%
students.append('Arun')

# %%
print(students)
# Out:
# ['Viky', 'abdul', 'shree', 'ansar', 'shuakat', 'Arun']

# %%
#request to add at perticular index

# %%
students.insert(2,'Taufique')

# %%
print(students)
# Out:
# ['Viky', 'abdul', 'Taufique', 'shree', 'ansar', 'shuakat', 'Arun']

# %%
#request to modify certain index

# %%
students[2]='Aali'

# %%
print(students)
# Out:
# ['Viky', 'abdul', 'Aali', 'shree', 'ansar', 'shuakat', 'Arun']

# %%
#req to delete(temp and permanent) using pop and

# %%
x=students.pop()

# %%
print(students)
# Out:
# ['Viky', 'abdul', 'Aali', 'shree', 'ansar', 'shuakat']

# %%
print(x)
# Out:
# Arun

# %%
#to delete index

# %%
d
